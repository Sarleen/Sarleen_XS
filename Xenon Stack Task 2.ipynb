# %%
pip install mysql.connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tkinter import *
from tkinter import ttk, messagebox

# page 1
root =Tk()
root.geometry('600x500')
root.title('Employment Management System')
root.resizable(width = True, height = True)
root.config(bg = 'black')

# label ( showing the heading of main page (page 1)):
l=Label (root,text='WELCOME TO OUR SERVICES ',width=30,height=1,font=('Helvetica', 30, 'bold'),bg='black',fg='white')
l.pack()

#Creating function for company page 
def companypage():
    root3= Tk()
    root3.geometry('600x500')
    root3.title('Employment Management System')
    root3.resizable(width = True, height = True)
    root3.config(bg = 'black')

    # label ( showing the heading of company page):
    m=Label (root3,width=30,height=1,font=('Helvetica', 30, 'bold'),bg='black',fg='white')
    m.place(x=300,y=300)
    m.configure(text = f'welcome to our company page..')
    b1 = Button(root1, text = 'SUBMIT', font=('Helvetica', 20, 'bold'), width = 7,
          height = 1, bg = 'skyblue', fg = 'black', bd = 2, relief = 'solid',
           activebackground = 'yellow',command = submitlogin)
    b1.place(x = 250, y = 250)
    root1.mainloop()
    
#creating function to login window
def login():
    root1= Tk()
    root1.geometry('600x500')
    root1.title('Login page')
    root1.resizable(width = True, height = True)
    root1.config(bg = 'yellow')
    def submitlogin():
        p= Label(root1, bg = 'black', width = 40, height=1, font = ('Helvetica', 15, 'bold'), fg = 'crimson')
        p.place(x = 40, y = 350)
        
        user_1 = StringVar()
        passwd = StringVar()
        
        user_1= e1.get()
        passwd= e2.get()
        
        p.configure(text = f'welcome {user_1} to our services..')
        
        # sql connection
        import mysql.connector
    
        connection = mysql.connector.connect(host = 'localhost',user = 'root',password ='root',database = 'proj')
        if user_1=="" or passwd=="":
            messagebox.showerror("Error","Enter User Name And Password",parent=root1)
        else:
            try:
                cur = connection.cursor()

                cur.execute("select * from login where username=%s and password = %s",(user_1,passwd))
                row = cur.fetchone()

                if row==None:
                       messagebox.showerror("Error" , "Invalid User Name And Password, please Signup first", parent = root1)

                          
                else:
                    messagebox.showinfo("Success" , "Successfully Login" , parent = root1)
                   
                    companypage()
                    print("you are now going to company page")
                    
            except Exception as es:
                 messagebox.showerror("Error" , f"Error Due to : {str(es)}", parent = root1)
     
    # labels of login page 
    l1 = Label(root1, text='LOGIN PAGE', font=('Helvetica', 20, 'bold'), width = 10,
          height = 1, bg = 'black', fg = 'white', bd = 2, relief = 'solid')
    l1.pack()

    l2 = Label(root1, text='USERNAME', font=('Helvetica', 20, 'bold'), width = 10,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    l2.place(x = 100, y = 80)

    l3 = Label(root1, text='PASSWORD', font=('Helvetica', 20, 'bold'), width = 10,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    l3.place(x = 100, y = 160)

    # ENTRY:

    e1 = Entry(root1, width = 30, bg = 'lightgrey')
    e1.place(x = 300, y = 90)

    e2 = Entry(root1, width = 30, bg = 'lightgrey', show="*")
    e2.place(x = 300, y = 160)

    # Button:

    b1 = Button(root1, text = 'SUBMIT', font=('Helvetica', 20, 'bold'), width = 7,
          height = 1, bg = 'skyblue', fg = 'black', bd = 2, relief = 'solid',
           activebackground = 'yellow',command = submitlogin)
    b1.place(x = 250, y = 250)
    root1.mainloop()
    
#creating function signup 
def signup():
    root2=Tk()
    root2=Tk()
    root2.geometry('600x500')
    root2.title('Register')
    root2.resizable(width = True, height = True)
    root2.config(bg = 'black')
    def submitsignup():
       
        
        ename = StringVar()
        eage = StringVar()
        eid = StringVar()
        eadd = StringVar()
        ephno = StringVar()
        eemail = StringVar()
        edesg = StringVar()
        eloc = StringVar()
        eexp = StringVar()
        
        ename = a1.get()
        eage = a2.get()
        eid = a3.get()
        eadd = a4.get()
        ephno = a5.get()
        eemail = a6.get()
        edesg = a7.get()
        eloc = a8.get()
        eexp = a9.get()
        
        print(ephno)
        print(type(ephno))
        if ename =="" or eage =="" or eid =="" or eadd =="" or ephno =="" or eemail =="" or edesg=="" or eloc=="" or eexp =="":
            messagebox.showerror("Error" , "All Fields Are Required" , parent = root2)
        else:
            if (len(ephno)!=10):
                messagebox.showerror("Error" , "Field phone no required 10 digits" , parent = root2)
            
            # sql connection
            import mysql.connector

            connection = mysql.connector.connect(host = 'localhost',user = 'root',password ='root',database = 'proj')
            table_query2 ='''create table if not exists emp(name varchar(20),age varchar(20),id varchar(20),
            desg varchar(20),email varchar(20),phone varchar(20),state varchar(20), 
            experience varchar(20),location varchar(20))'''
            insert_query2 = 'insert into emp(name,age,id,state,phone,email,desg,location,experience)values(%s,%s,%s,%s,%s,%s,%s,%s,%s)'
            values2=(ename,eage,eid,eadd,ephno,eemail,edesg,eloc,eexp)

            # cursor class is used to execute the queries

            cur=connection.cursor()
            cur.execute(table_query2)
            cur.execute(insert_query2, values2)
            connection.commit()
            signup2()
            print("You have successfully registered")
            

                    
    # Labels:
    lab1 = Label(root2, text='PLEASE ENTER YOUR DETAILS ', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'white', bd = 2, relief = 'solid')
    lab1.pack()

    lab2 = Label(root2, text='Employee Name ', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lab2.place(x = 100, y = 40)

    lab3= Label(root2, text='Employee Age', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lab3.place(x = 100, y = 80)

    lab4 = Label(root2, text='Employee ID', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lab4.place(x = 100, y = 120)

    lab5 = Label(root2, text='Employee Address', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lab5.place(x = 100, y = 160)

    lab6 = Label(root2, text='Employee Phone No', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lab6.place(x = 100, y = 200)

    lab7 = Label(root2, text='Employee Email', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lab7.place(x = 100, y = 240)
    
    lab8 = Label(root2, text='Employee desgination', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lab8.place(x = 100, y = 280)
    
    lab9 = Label(root2, text='Employee Location', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lab9.place(x = 100, y = 320)
    
    lab10 = Label(root2, text='Employee Experience', font=('Helvetica', 20, 'bold'), width = 50,
          height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lab10.place(x = 100, y = 360)

    # ENTRY:

    a1 = Entry(root2, width = 50, bg = 'lightgrey')
    a1.place(x = 900, y = 40)

    a2 = Entry(root2, width = 50, bg = 'lightgrey')
    a2.place(x = 900, y = 80)

    a3 = Entry(root2, width = 50, bg = 'lightgrey')
    a3.place(x = 900, y = 120)

    a4 = Entry(root2, width = 50, bg = 'lightgrey')
    a4.place(x = 900, y = 160)

    a5 = Entry(root2, width = 50, bg = 'lightgrey')
    a5.place(x = 900, y = 200)

    a6 = Entry(root2, width = 50, bg = 'lightgrey')
    a6.place(x = 900, y = 240)
    
    a7 = Entry(root2, width = 50, bg = 'lightgrey')
    a7.place(x = 900, y = 280)

    a8 = Entry(root2, width = 50, bg = 'lightgrey')
    a8.place(x = 900, y = 320)

    a9 = Entry(root2, width = 50, bg = 'lightgrey')
    a9.place(x = 900, y = 360)
    
    b2 = Button(root2, text = 'SUBMIT', font=('Helvetica', 20, 'bold'), width = 7,
          height = 1, bg = 'skyblue', fg = 'black', bd = 2, relief = 'solid',
           activebackground = 'yellow',command = submitsignup)
    b2.place(x = 750, y = 400)
    root2.mainloop()
    
# create a function page username, password ,create password
def signup2():
    global r1
    global r2
    global r3
    global root4
    root4=Tk()
    root4.geometry('600x500')
    root4.title('Signup')
    root4.resizable(width = True, height = True)
    root4.config(bg = 'black')
    
    #labels
    lb1 = Label(root4, text='CREATE YOUR PASSWORD ', font=('Helvetica', 20, 'bold'), width = 50,
                  height = 1, bg = 'black', fg = 'white', bd = 2, relief = 'solid')
    lb1.pack()

    lb2 = Label(root4, text='Username ', font=('Helvetica', 20, 'bold'), width = 50,
                  height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lb2.place(x = 100, y = 40)
                
    lb3 = Label(root4, text='New Password', font=('Helvetica', 20, 'bold'), width = 50,
                  height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lb3.place(x = 100, y = 80)
                
    lb4= Label(root4, text='Rewrite Password', font=('Helvetica', 20, 'bold'), width = 50,
                  height = 1, bg = 'black', fg = 'yellow', bd = 2, relief = 'solid')
    lb4.place(x = 100, y = 120)
    
    
    #entry
    r1 = Entry(root4, width = 50, bg = 'lightgrey')
    r1.place(x = 900, y = 40)

    r2 = Entry(root4, width = 50, bg = 'lightgrey')
    r2.place(x = 900, y = 80)

    r3 = Entry(root4, width = 50, bg = 'lightgrey')
    r3.place(x = 900, y = 120)
                
    #Button
    butt= b2 = Button(root4, text = 'LOGIN NOW', font=('Helvetica', 20, 'bold'), width = 7,
                height = 1, bg = 'skyblue', fg = 'black', bd = 2, relief = 'solid',
                activebackground = 'yellow',command=login_db)
    butt.place(x = 750, y = 200)
    
    root4.mainloop()

def login_db():
    uname = StringVar()
    new_pass = StringVar()
    re_pass = StringVar()
    
    
    uname = r1.get()
    new_pass = r2.get()
    re_pass = r3.get()
                
    if new_pass!=re_pass:
        messagebox.showerror("Error" , "Password is not matching" , parent = root4)
                
    else:
        import mysql.connector
    
        connection = mysql.connector.connect(host = 'localhost',user = 'root',password ='root',database = 'proj')
        table_query1 ='''create table if not exists login(username varchar(20), password varchar(20))'''
        insert_query1 = 'insert into login(username,password) values(%s,%s)'
        values1=(uname,new_pass)

        # cursor class is used to execute the queries
    
        cur=connection.cursor()
        cur.execute(table_query1)
        cur.execute(insert_query1, values1)
        connection.commit()
        messagebox.showinfo("Success" , "You can login now" , parent = root4)
        login()
             
# creating function to destroy window
def quit():
    root.destroy()

# Buttons on first page (login /signup)
login_button = Button(root, text = 'Login', font=('Helvetica', 20, 'bold'), width = 7,
          height = 1, bg = 'skyblue', fg = 'black', bd = 2, relief = 'solid',
           activebackground = 'yellow',command=login)
login_button.place(x = 700, y = 100)
signup_button = Button(root, text = 'Signup', font=('Helvetica', 20, 'bold'), width = 7,
          height = 1, bg = 'skyblue', fg = 'black', bd = 2, relief = 'solid',
           activebackground = 'yellow',command=signup)
signup_button.place(x = 700, y = 200)
quit_button = Button(root, text = 'Quit', font=('Helvetica', 20, 'bold'), width = 7,
          height = 1, bg = 'skyblue', fg = 'black', bd = 2, relief = 'solid',
           activebackground = 'yellow',command=quit)
quit_button.place(x = 700, y = 300)
root.mainloop()
# Out:
# <class 'str'>
# 9874563210
# <class 'str'>
